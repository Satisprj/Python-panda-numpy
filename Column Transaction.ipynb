# %%
import pandas as pd

# %%
data=pd.read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 897          224         0       3
# 898          225         1       1
# 899          226         0       3
# 900          227         1       2
# 901          228         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#add new column
data.loc[(data["Fare"]<10),"HighFare"]="Yes"
data.loc[(data["Fare"]>10),"HighFare"]="No"
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data["Sex-Embarked"]=data["Sex"]+"-"+data["Embarked"]
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 897          224         0       3
# 898          225         1       1
# 899          226         0       3
# 900          227         1       2
# 901          228         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data=pd.read_excel('ESD.xlsx')
data
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
data.head(10)
# Out:
#      EEID        Full Name                 Job Title  Department  \
# 0  E02387      Emily Davis                Sr. Manger          IT
# 1  E04105    Theodore Dinh       Technical Architect          IT
# 2  E02572     Luna Sanders                  Director     Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager          IT
# 4  E01639        Austin Vo               Sr. Analyst     Finance
# 5  E00644     Joshua Gupta    Account Representative       Sales
# 6  E01550      Ruby Barnes                   Manager          IT
# 7  E04332      Luke Martin                   Analyst     Finance
# 8  E04533    Easton Bailey                   Manager  Accounting
# 9  E03838  Madeline Walker               Sr. Analyst     Finance
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# ...

# %%
gp = data.groupby("Department").agg({"Gender":"count"})
gp
# Out:
#                  Gender
# Department
# Accounting           96
# Engineering         158
# Finance             120
# Human Resources     125
# IT                  241
# Marketing           120
# Sales               140

# %%
gp=data.groupby(["Department","Gender"]).agg({"EEID":"count"})
gp
# Out:
#                         EEID
# Department      Gender
# Accounting      Female    53
#                 Male      43
# Engineering     Female    80
#                 Male      78
# Finance         Female    69
#                 Male      51
# Human Resources Female    64
#                 Male      61
# IT              Female   119
#                 Male     122
# Marketing       Female    57
#                 Male      63
# Sales           Female    76
#                 Male      64

# %%
gp=data.groupby(["Department"]).agg({"Annual Salary":"max"})
gp
# Out:
#                  Annual Salary
# Department
# Accounting              258426
# Engineering             255431
# Finance                 255369
# Human Resources         250953
# IT                      256561
# Marketing               257194
# Sales                   258498

# %%
import pandas as pd

# %%
data={"Emp id":["E01","E02","E03","E04","E05"],"Names":["Satis","Swornim","Prabal","Simon","Rohan"],"Age":[21,22,23,21,23]}
data2={"Emp id":["E01","E02","E03","E04","E05"],"Salary":[2100,2200,2300,2100,2300]}
df=pd.DataFrame(data)
df1=pd.DataFrame(data2)

print(df)
print()
print(df1)
# Out:
#   Emp id    Names  Age
# 0    E01    Satis   21
# 1    E02  Swornim   22
# 2    E03   Prabal   23
# 3    E04    Simon   21
# 4    E05    Rohan   23
#
#   Emp id  Salary
# 0    E01    2100
# 1    E02    2200
# 2    E03    2300
# 3    E04    2100
# 4    E05    2300

# %%
#merge the column
print(pd.merge(df,df1,on="Emp id"))
# Out:
#   Emp id    Names  Age  Salary
# 0    E01    Satis   21    2100
# 1    E02  Swornim   22    2200
# 2    E03   Prabal   23    2300
# 3    E04    Simon   21    2100
# 4    E05    Rohan   23    2300
